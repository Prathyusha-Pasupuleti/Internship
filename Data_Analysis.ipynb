# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha-Pasupuleti/Internship/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
datasetPath ='/content/drive/MyDrive/retail_transactions.csv'

# %%
df = pd.read_csv(datasetPath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
#1.Data loading and phrasing

# %%
from datetime import datetime

# %%
df['TransactionDate']=pd.to_datetime(df['TransactionDate'])

# %%
#2 .Initial Data Exploration

# %%
#Displsy first 15 rows in DataFrame

df.head(15)
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# 6           T007      2024-01-07      103        1983        586
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# 9           T010      2024-01-10      101        1711        565
# 10          T011      2024-01-11      103        1276        565
# 11          T012      2024-01-12      101        1486        523
# 12          T013      2024-01-13      103        1597        516
# ...

# %%
#print summary info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    datetime64[ns]
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         100 non-null    float64
#  10  NetPrice         100 non-null    float64
#  11  TotalSale        100 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(3)
# memory usage: 9.5+ KB

# %%
#print summary describe()
df.describe()
# Out:
#            TransactionDate     StoreID   CustomerID   ProductID    Quantity  \
# count                  100  100.000000   100.000000  100.000000  100.000000
# mean   2024-02-19 12:00:00  102.730000  1552.520000  554.390000    5.370000
# min    2024-01-01 00:00:00  101.000000  1013.000000  501.000000    1.000000
# 25%    2024-01-25 18:00:00  101.000000  1310.250000  529.750000    3.000000
# 50%    2024-02-19 12:00:00  103.000000  1534.000000  554.000000    5.500000
# 75%    2024-03-15 06:00:00  104.000000  1800.750000  579.500000    8.000000
# max    2024-04-09 00:00:00  105.000000  1983.000000  600.000000   10.000000
# std                    NaN    1.384291   268.295461   28.544098    3.013957
#
#            Price   Discount    NetPrice    TotalSale
# count  100.00000  100.00000  100.000000   100.000000
# mean   282.15000    5.80000  266.211000  1456.037000
# min     50.00000    0.00000   50.000000    80.100000
# 25%    165.75000    0.00000  160.375000   453.150000
# ...

# %%
#3. Data Cleaning

# %%
#Check for missing values
df.isnull().sum()
# Out:
# TransactionID      0
# TransactionDate    0
# StoreID            0
# CustomerID         0
# ProductID          0
# ProductCategory    0
# Quantity           0
# Price              0
# PaymentType        0
# Discount           0
# NetPrice           0
# TotalSale          0
# dtype: int64

# %%
#print count per column
df.count()
# Out:
# TransactionID      100
# TransactionDate    100
# StoreID            100
# CustomerID         100
# ProductID          100
# ProductCategory    100
# Quantity           100
# Price              100
# PaymentType        100
# Discount           100
# NetPrice           100
# TotalSale          100
# dtype: int64

# %%
#for the columns Quality,Price and Discount ensure they are in numeric format

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Discount'] = pd.to_numeric(df['Discount'], errors='coerce')

# %%
df['Discount'] = df['Discount'].fillna(0)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
df['NetPrice'] = df['Price'] * (1 - df['Discount'] / 100)

# %%
df['NetPrice']
# Out:
# 0     127.50
# 1     285.30
# 2     165.00
# 3     446.40
# 4     166.00
#        ...
# 95    395.10
# 96     52.00
# 97    135.90
# 98    431.10
# 99    209.95
# Name: NetPrice, Length: 100, dtype: float64

# %%
df['TotalSale'] = df['Quantity'] * df['NetPrice']

# %%
df['TotalSale']
# Out:
# 0      127.50
# 1      570.60
# 2      825.00
# 3     2678.40
# 4     1660.00
#        ...
# 95     790.20
# 96     208.00
# 97     951.30
# 98    2155.50
# 99    1049.75
# Name: TotalSale, Length: 100, dtype: float64

# %%
filtered_df = df[df['TotalSale'] >= 20]

# %%
filtered_df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
df1 = filtered_df

# %%
df1
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# ...

# %%
filtered_df['PaymentType'] = filtered_df['PaymentType'].astype('category')

# %%
filtered_df['PaymentType']
# Out:
# 0     Credit
# 1      Debit
# 2      Debit
# 3      Debit
# 4      Debit
#        ...
# 95      Cash
# 96     Debit
# 97    Credit
# 98    Credit
# 99    Credit
# Name: PaymentType, Length: 100, dtype: category
# Categories (3, object): ['Cash', 'Credit', 'Debit']

# %%
category_sales = filtered_df.groupby('ProductCategory').agg(
    TotalQuantity=('Quantity', 'sum'),
    TotalSales=('TotalSale', 'sum')
)

# %%
category_sales = category_sales.sort_values(by='TotalSales', ascending=False)

# %%
category_sales
# Out:
#                  TotalQuantity  TotalSales
# ProductCategory
# Toys                       137    44326.35
# Furniture                  130    39655.55
# Apparel                    117    28055.35
# Grocery                     75    17585.80
# Electronics                 78    15980.65

# %%
top_3_categories = category_sales.head(3)

# %%
top_3_categories
# Out:
#                  TotalQuantity  TotalSales
# ProductCategory
# Toys                       137    44326.35
# Furniture                  130    39655.55
# Apparel                    117    28055.35

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
store_category_sales
# Out:
#     StoreID ProductCategory    TotalSale
# 0       101         Apparel  1344.550000
# 1       101     Electronics  1128.916667
# 2       101       Furniture  1317.943750
# 3       101            Toys  2227.016667
# 4       102         Apparel  1452.180000
# 5       102     Electronics   591.380000
# 6       102       Furniture  2565.900000
# 7       102         Grocery   171.900000
# 8       102            Toys  1036.557143
# 9       103         Apparel  1021.950000
# 10      103     Electronics   817.666667
# 11      103       Furniture  1560.771429
# 12      103         Grocery   954.850000
# 13      103            Toys  1239.180000
# 14      104         Apparel   722.000000
# 15      104     Electronics   852.333333
# 16      104       Furniture  1528.928571
# 17      104         Grocery  1118.833333
# 18      104            Toys  1367.700000
# 19      105         Apparel  2398.450000
# 20      105     Electronics  2313.500000
# 21      105       Furniture  1176.150000
# ...

# %%
top_category_per_store = store_category_sales.loc[store_category_sales.groupby('StoreID')['TotalSale'].idxmax()]

# %%
top_category_per_store
# Out:
#     StoreID ProductCategory    TotalSale
# 3       101            Toys  2227.016667
# 6       102       Furniture  2565.900000
# 11      103       Furniture  1560.771429
# 16      104       Furniture  1528.928571
# 23      105            Toys  4048.000000
