# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha-Pasupuleti/Internship/blob/main/Introductionof_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
  a1.append(random.randint(0, 100))
  a2.append(random.randint(50, 100))
  a3.append(random.randint(10, 100))
  a4.append(random.randint(5, 100))
  a5.append(random.randint(20, 100))

# %%
df = {
    'grade' : a1 ,
    'weight' : a2 ,
    'friends' : a3 ,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       15      60       74       89        94
# 1       33      80       26       13        87
# 2       48      68       51       56        85
# 3       48      97       77       11        22
# 4       55      89       92       55        69
# ..     ...     ...      ...      ...       ...
# 995     26      54       68       54        42
# 996     45      69       82       47        28
# 997      1      50       99       34        39
# 998     82      96       40       22        61
# 999     15      69       17       78        40
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     48.675000    74.546000    55.093000    51.578000    59.127000
# std      28.844226    14.686169    26.505639    28.076185    22.539008
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      24.000000    61.750000    32.000000    26.000000    40.000000
# 50%      48.000000    75.000000    56.000000    53.000000    59.000000
# 75%      73.000000    87.000000    79.000000    74.250000    78.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      15
# 1      33
# 2      48
# 3      48
# 4      55
#        ..
# 995    26
# 996    45
# 997     1
# 998    82
# 999    15
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15 = df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       15      60       74       89        94
# 1       33      80       26       13        87
# 2       48      68       51       56        85
# 3       48      97       77       11        22
# 4       55      89       92       55        69
# ..     ...     ...      ...      ...       ...
# 995     26      54       68       54        42
# 996     45      69       82       47        28
# 997      1      50       99       34        39
# 998     82      96       40       22        61
# 999     15      69       17       78        40
#
# [936 rows x 5 columns]

# %%
grade75 = df1['grade']>75

# %%
df1[grade75]
# Out:
#      grade  weight  friends  cousins  projects
# 9       91      59       59       87        27
# 12      78      59       68       60        33
# 13      84      98       57       26        57
# 14      77      79      100       16        66
# 22     100      98       36       31        30
# ..     ...     ...      ...      ...       ...
# 980     94      76       45       10        50
# 986     91      70       16       62        85
# 990     99      51       96        5        89
# 992     86      94       39       93        81
# 998     82      96       40       22        61
#
# [228 rows x 5 columns]

# %%
df1[grade75 & friend15].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 76     55      21       66       24          1
# 92     57      88       48       94          1
#        68      88       55       21          1
#        73      97       14       24          1
#        79      71       72       32          1
#                                             ..
# 85     62      41       10       49          1
#        76      22       94       38          1
#        83      23       21       68          1
#        99      38       38       59          1
# 100    98      36       31       30          1
# Name: count, Length: 215, dtype: int64

# %%
df1[friend15 & grade75]['weight'].value_counts()
# Out:
# weight
# 79     9
# 57     9
# 99     8
# 62     8
# 59     7
# 51     7
# 81     7
# 82     6
# 69     6
# 61     6
# 97     6
# 76     6
# 60     6
# 96     6
# 80     6
# 65     5
# 98     5
# 53     5
# 71     5
# 67     5
# 84     5
# 95     5
# 55     4
# 72     4
# 54     4
# 93     4
# 100    4
# 89     4
# 90     4
# 94     4
# 83     3
# 70     3
# 77     3
# 52     3
# 73     3
# 74     3
# 68     3
# 88     2
# 58     2
# 64     2
# 63     2
# 78     2
# 66     2
# 75     2
# 87     2
# 86     2
# 85     2
# 56     1
# 91     1
# 92     1
# 50     1
# Name: count, dtype: int64

# %%
df1[friend15 & grade75]['friends']
# Out:
# 9       59
# 12      68
# 13      57
# 14     100
# 22      36
#       ...
# 980     45
# 986     16
# 990     96
# 992     39
# 998     40
# Name: friends, Length: 215, dtype: int64

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x ='grade',y ='projects',kind = 'area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade75].plot(x ='grade',y ='projects',kind = 'bar')
# Out:
# <Axes: xlabel='grade'>

# %%
fdf= df1[friend15 & grade75]
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       15      60       74       89        94
# 1       33      80       26       13        87
# 2       48      68       51       56        85
# 3       48      97       77       11        22
# 4       55      89       92       55        69
# ..     ...     ...      ...      ...       ...
# 995     26      54       68       54        42
# 996     45      69       82       47        28
# 997      1      50       99       34        39
# 998     82      96       40       22        61
# 999     15      69       17       78        40
#
# [1000 rows x 5 columns]

# %%
df1.to_csv(r'C:\Users\prath\OneDrive\Desktop\Python\listof_ascendingOrder.ipynb')
