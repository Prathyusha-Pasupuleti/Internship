# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
  a1.append(random.randint(0, 100))
  a2.append(random.randint(50, 100))
  a3.append(random.randint(10, 100))
  a4.append(random.randint(5, 100))
  a5.append(random.randint(20, 100))

# %%
df = {
    'grade' : a1 ,
    'weight' : a2 ,
    'friends' : a3 ,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       45      93       64       93        68
# 1       14      70       68       66        38
# 2       75     100       59       74        48
# 3       77      98       84       98        83
# 4       50      64       51       63        66
# ..     ...     ...      ...      ...       ...
# 995     70      64       91      100        29
# 996     13      58       58       35        81
# 997     47      96       58       43        89
# 998     10      55       66       56        27
# 999     18      78       57       94        49
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#             grade       weight      friends      cousins    projects
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     48.98400    75.655000    54.561000    53.472000    60.70300
# std      29.26777    14.728303    26.717449    27.449384    23.28263
# min       0.00000    50.000000    10.000000     5.000000    20.00000
# 25%      23.00000    63.000000    32.000000    29.750000    41.00000
# 50%      49.00000    75.000000    55.000000    54.500000    61.00000
# 75%      74.00000    89.000000    79.000000    77.250000    81.00000
# max     100.00000   100.000000   100.000000   100.000000   100.00000

# %%
df1['grade'].count()
# Out:
# np.int64(1000)

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      45
# 1      14
# 2      75
# 3      77
# 4      50
#        ..
# 995    70
# 996    13
# 997    47
# 998    10
# 999    18
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15 = df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       45      93       64       93        68
# 1       14      70       68       66        38
# 2       75     100       59       74        48
# 3       77      98       84       98        83
# 4       50      64       51       63        66
# ..     ...     ...      ...      ...       ...
# 995     70      64       91      100        29
# 996     13      58       58       35        81
# 997     47      96       58       43        89
# 998     10      55       66       56        27
# 999     18      78       57       94        49
#
# [926 rows x 5 columns]

# %%
grade75 = df1['grade']>75

# %%
df1[grade75]
# Out:
#      grade  weight  friends  cousins  projects
# 3       77      98       84       98        83
# 13      96      84       16       80        77
# 14      99      76       75       64        68
# 16      90      63       69       78        36
# 18      95      50       36       69        85
# ..     ...     ...      ...      ...       ...
# 970     86      60       25       98        49
# 971     84      60       87       72        37
# 977     97      81       50       74        24
# 989     98      70       61      100        32
# 991     93      86       55       43        69
#
# [231 rows x 5 columns]

# %%
df1[grade75 & friend15].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 76     53      39       96       89          1
#        74      54       33       44          1
#        80      34       74       74          1
#                43       79       95          1
#        83      40       54       35          1
#                                             ..
# 100    79      56       7        54          1
#        84      82       78       90          1
#        88      39       15       42          1
#                59       57       87          1
#        92      49       43       97          1
# Name: count, Length: 216, dtype: int64

# %%
df1[friend15 & grade75]['weight'].value_counts()
# Out:
# weight
# 88     9
# 80     9
# 98     7
# 90     7
# 92     7
# 61     7
# 81     7
# 71     6
# 84     6
# 64     6
# 62     6
# 91     6
# 83     5
# 56     5
# 76     5
# 75     5
# 82     5
# 60     5
# 65     5
# 58     5
# 87     5
# 97     5
# 100    5
# 69     5
# 96     4
# 59     4
# 66     4
# 73     3
# 74     3
# 63     3
# 50     3
# 89     3
# 95     3
# 52     3
# 54     3
# 85     3
# 70     3
# 53     3
# 55     3
# 94     3
# 86     3
# 67     2
# 72     2
# 99     2
# 78     2
# 79     2
# 77     2
# 51     2
# 68     2
# 93     2
# 57     1
# Name: count, dtype: int64

# %%
df1[friend15 & grade75]['friends']
# Out:
# 3      84
# 13     16
# 14     75
# 16     69
# 18     36
#        ..
# 970    25
# 971    87
# 977    50
# 989    61
# 991    55
# Name: friends, Length: 216, dtype: int64

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade75].plot(x= 'grade' , y='projects' , kind='bar', title='Sample Graph')
plt.xlabel('X Axis')
plt.xlabel('Y Axis')
plt.legend('Test Data')
plt.show()

# %%
df1[friend15 & grade75].plot(x = 'grade', y='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade75].plot(x='grade',y='projects',kind='box')
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x='grade',y='projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend15 & grade75].plot(x='projects',y='weight',kind='pie')
# Out:
# <Axes: ylabel='weight'>

# %%
df1[friend15 & grade75].plot(x='grade',y='projects',kind='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade75].plot(x='grade',y='projects',kind='barh')
# Out:
# <Axes: ylabel='grade'>

# %%
fdf = df1[friend15 & grade75]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 3       77      98       84       98        83
# 13      96      84       16       80        77
# 14      99      76       75       64        68
# 16      90      63       69       78        36
# 18      95      50       36       69        85
# ..     ...     ...      ...      ...       ...
# 970     86      60       25       98        49
# 971     84      60       87       72        37
# 977     97      81       50       74        24
# 989     98      70       61      100        32
# 991     93      86       55       43        69
#
# [216 rows x 5 columns]
