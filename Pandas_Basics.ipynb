# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathyusha-Pasupuleti/Introduction-of-Pandas/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [76,
#   12,
#   36,
#   19,
#   65,
#   79,
#   81,
#   95,
#   74,
#   15,
#   99,
#   38,
#   8,
#   76,
#   86,
#   78,
#   90,
#   70,
#   8,
#   26,
#   46,
#   52,
#   67,
#   6,
#   49,
#   29,
#   51,
#   70,
#   83,
#   75,
#   76,
#   24,
#   88,
#   85,
#   7,
#   26,
#   18,
#   81,
#   26,
#   78,
#   89,
#   64,
#   86,
#   12,
#   46,
#   76,
#   55,
#   86,
#   59,
#   15,
#   7,
#   11,
#   70,
#   60,
#   92,
#   82,
#   76,
#   0,
#   71,
#   31,
#   89,
#   68,
#   43,
#   20,
#   30,
#   23,
#   18,
#   97,
#   25,
#   48,
#   60,
#   5,
#   60,
#   96,
#   30,
#   22,
#   39,
#   81,
#   57,
#   33,
#   86,
#   37,
#   20,
#   95,
#   87,
#   5,
#   40,
#   31,
#   59,
#   24,
#   31,
#   10,
#   52,
#   20,
#   90,
#   0,
#   75,
#   29,
#   22,
#   18],
#  'Height': [54,
#   37,
#   23,
#   25,
#   92,
#   25,
#   57,
#   4,
#   93,
#   75,
#   80,
#   24,
#   53,
#   17,
#   100,
#   71,
#   47,
#   9,
#   50,
#   32,
#   82,
#   90,
#   30,
#   79,
#   97,
#   6,
#   21,
#   99,
#   50,
#   42,
#   60,
#   6,
#   91,
#   55,
#   30,
#   24,
#   4,
#   78,
#   19,
#   63,
#   37,
#   45,
#   65,
#   35,
#   0,
#   19,
#   67,
#   41,
#   88,
#   88,
#   33,
#   12,
#   66,
#   65,
#   26,
#   67,
#   82,
#   71,
#   68,
#   96,
#   89,
#   53,
#   88,
#   28,
#   42,
#   93,
#   88,
#   54,
#   74,
#   61,
#   44,
#   17,
#   62,
#   75,
#   83,
#   3,
#   56,
#   84,
#   66,
#   54,
#   97,
#   40,
#   10,
#   16,
#   28,
#   14,
#   80,
#   11,
#   2,
#   75,
#   49,
#   21,
#   53,
#   10,
#   49,
#   60,
#   0,
#   56,
#   12,
#   68],
#  'Weight': [28,
#   16,
#   19,
#   100,
#   87,
#   53,
#   5,
#   73,
#   23,
#   83,
#   92,
#   45,
#   44,
#   45,
#   13,
#   59,
#   70,
#   35,
#   70,
#   14,
#   75,
#   29,
#   7,
#   49,
#   37,
#   0,
#   41,
#   38,
#   18,
#   82,
#   91,
#   50,
#   35,
#   86,
#   20,
#   16,
#   78,
#   35,
#   20,
#   18,
#   36,
#   55,
#   76,
#   82,
#   65,
#   85,
#   87,
#   83,
#   38,
#   97,
#   75,
#   1,
#   2,
#   16,
#   99,
#   2,
#   80,
#   14,
#   39,
#   34,
#   94,
#   76,
#   63,
#   14,
#   36,
#   87,
#   28,
#   83,
#   9,
#   53,
#   28,
#   91,
#   41,
#   92,
#   68,
#   49,
#   40,
#   42,
#   42,
#   91,
#   47,
#   93,
#   100,
#   64,
#   47,
#   26,
#   76,
#   66,
#   2,
#   98,
#   98,
#   51,
#   33,
#   87,
#   83,
#   79,
#   42,
#   24,
#   14,
#   41],
#  'Speed': [2,
#   85,
#   11,
#   93,
#   76,
#   93,
#   56,
#   94,
#   1,
#   47,
#   6,
#   0,
#   24,
#   27,
#   61,
#   73,
#   31,
#   94,
#   81,
#   69,
#   18,
#   12,
#   68,
#   53,
#   79,
#   14,
#   68,
#   42,
#   80,
#   94,
#   72,
#   93,
#   23,
#   56,
#   36,
#   90,
#   54,
#   59,
#   97,
#   20,
#   60,
#   86,
#   14,
#   85,
#   42,
#   24,
#   22,
#   26,
#   69,
#   69,
#   94,
#   90,
#   97,
#   47,
#   19,
#   82,
#   28,
#   50,
#   48,
#   65,
#   52,
#   59,
#   90,
#   38,
#   58,
#   47,
#   39,
#   16,
#   76,
#   94,
#   100,
#   81,
#   34,
#   31,
#   86,
#   37,
#   73,
#   3,
#   34,
#   84,
#   7,
#   78,
#   42,
#   33,
#   77,
#   12,
#   32,
#   0,
#   52,
#   5,
#   10,
#   18,
#   9,
#   92,
#   37,
#   22,
#   37,
#   60,
#   72,
#   25]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    76      54      28      2
# 1    12      37      16     85
# 2    36      23      19     11
# 3    19      25     100     93
# 4    65      92      87     76
# ..  ...     ...     ...    ...
# 95    0      60      79     22
# 96   75       0      42     37
# 97   29      56      24     60
# 98   22      12      14     72
# 99   18      68      41     25
#
# [100 rows x 4 columns]

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.310000   50.300000   51.630000   51.210000
# std     29.661625   29.117144   29.820898   29.969444
# min      0.000000    0.000000    0.000000    0.000000
# 25%     23.750000   24.750000   28.000000   24.750000
# 50%     51.500000   53.000000   47.000000   52.000000
# 75%     76.500000   75.000000   80.500000   78.250000
# max     99.000000  100.000000  100.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    76      54
# 1    12      37
# 2    36      23
# 3    19      25
# 4    65      92
# ..  ...     ...
# 95    0      60
# 96   75       0
# 97   29      56
# 98   22      12
# 99   18      68
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   76      54
# 3   19      25

# %%
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0    76      54      28      2
# 2    36      23      19     11
# 4    65      92      87     76
# 6    81      57       5     56
# 8    74      93      23      1
# 10   99      80      92      6
# 12    8      53      44     24
# 14   86     100      13     61
# 16   90      47      70     31
# 18    8      50      70     81
# 20   46      82      75     18
# 22   67      30       7     68
# 24   49      97      37     79
# 26   51      21      41     68
# 28   83      50      18     80
# 30   76      60      91     72
# 32   88      91      35     23
# 34    7      30      20     36
# 36   18       4      78     54
# 38   26      19      20     97
# 40   89      37      36     60
# 42   86      65      76     14
# 44   46       0      65     42
# 46   55      67      87     22
# 48   59      88      38     69
# 50    7      33      75     94
# 52   70      66       2     97
# 54   92      26      99     19
# 56   76      82      80     28
# 58   71      68      39     48
# 60   89      89      94     52
# 62   43      88      63     90
# 64   30      42      36     58
# 66   18      88      28     39
# 68   25      74       9     76
# 70   60      44      28    100
# 72   60      62      41     34
# 74   30      83      68     86
# 76   39      56      40     73
# 78   57      66      42     34
# 80   86      97      47      7
# 82   20      10     100     42
# 84   87      28      47     77
# 86   40      80      76     32
# 88   59       2       2     52
# 90   31      49      98     10
# 92   52      53      33      9
# 94   90      49      83     37
# 96   75       0      42     37
# 98   22      12      14     72

# %%
df1[0::2]. describe()
# Out:
#              Age      Height      Weight       Speed
# count  50.000000   50.000000   50.000000   50.000000
# mean   55.960000   54.740000   49.220000   49.080000
# std    27.190154   29.134319   29.542284   28.774876
# min     7.000000    0.000000    2.000000    1.000000
# 25%    32.250000   30.750000   28.000000   25.000000
# 50%    59.000000   55.000000   41.500000   50.000000
# 75%    79.750000   81.500000   75.750000   72.750000
# max    99.000000  100.000000  100.000000  100.000000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    76      54      28      2
# 1    12      37      16     85
# 2    36      23      19     11
# 3    19      25     100     93
# 4    65      92      87     76
# ..  ...     ...     ...    ...
# 95    0      60      79     22
# 96   75       0      42     37
# 97   29      56      24     60
# 98   22      12      14     72
# 99   18      68      41     25
#
# [100 rows x 4 columns]

# %%
 filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 3    19      25     100     93
# 4    65      92      87     76
# 5    79      25      53     93
# 7    95       4      73     94
# 9    15      75      83     47
# 10   99      80      92      6
# 15   78      71      59     73
# 16   90      47      70     31
# 18    8      50      70     81
# 20   46      82      75     18
# 29   75      42      82     94
# 30   76      60      91     72
# 33   85      55      86     56
# 36   18       4      78     54
# 41   64      45      55     86
# 42   86      65      76     14
# 43   12      35      82     85
# 44   46       0      65     42
# 45   76      19      85     24
# 46   55      67      87     22
# 47   86      41      83     26
# 49   15      88      97     69
# 50    7      33      75     94
# 54   92      26      99     19
# 56   76      82      80     28
# 60   89      89      94     52
# 61   68      53      76     59
# 62   43      88      63     90
# 65   23      93      87     47
# 67   97      54      83     16
# 69   48      61      53     94
# 71    5      17      91     81
# 73   96      75      92     31
# 74   30      83      68     86
# 79   33      54      91     84
# 81   37      40      93     78
# 82   20      10     100     42
# 83   95      16      64     33
# 86   40      80      76     32
# 87   31      11      66      0
# 89   24      75      98      5
# 90   31      49      98     10
# 91   10      21      51     18
# 93   20      10      87     92
# 94   90      49      83     37
# 95    0      60      79     22

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 3    19      25     100     93
# 4    65      92      87     76
# 5    79      25      53     93
# 7    95       4      73     94
# 9    15      75      83     47
# 10   99      80      92      6
# 15   78      71      59     73
# 16   90      47      70     31
# 18    8      50      70     81
# 20   46      82      75     18
# 29   75      42      82     94
# 30   76      60      91     72
# 33   85      55      86     56
# 36   18       4      78     54
# 41   64      45      55     86
# 42   86      65      76     14
# 43   12      35      82     85
# 44   46       0      65     42
# 45   76      19      85     24
# 46   55      67      87     22
# 47   86      41      83     26
# 49   15      88      97     69
# 50    7      33      75     94
# 54   92      26      99     19
# 56   76      82      80     28
# 60   89      89      94     52
# 61   68      53      76     59
# 62   43      88      63     90
# 65   23      93      87     47
# 67   97      54      83     16
# 69   48      61      53     94
# 71    5      17      91     81
# 73   96      75      92     31
# 74   30      83      68     86
# 79   33      54      91     84
# 81   37      40      93     78
# 82   20      10     100     42
# 83   95      16      64     33
# 86   40      80      76     32
# 87   31      11      66      0
# 89   24      75      98      5
# 90   31      49      98     10
# 91   10      21      51     18
# 93   20      10      87     92
# 94   90      49      83     37
# 95    0      60      79     22

# %%
filter2 =df1['Age'] > 50

# %%
df1[filter1 &filter2]
# Out:
#     Age  Height  Weight  Speed
# 4    65      92      87     76
# 5    79      25      53     93
# 7    95       4      73     94
# 10   99      80      92      6
# 15   78      71      59     73
# 16   90      47      70     31
# 29   75      42      82     94
# 30   76      60      91     72
# 33   85      55      86     56
# 41   64      45      55     86
# 42   86      65      76     14
# 45   76      19      85     24
# 46   55      67      87     22
# 47   86      41      83     26
# 54   92      26      99     19
# 56   76      82      80     28
# 60   89      89      94     52
# 61   68      53      76     59
# 67   97      54      83     16
# 73   96      75      92     31
# 83   95      16      64     33
# 94   90      49      83     37

# %%
df1.loc[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 4    65      92      87     76
# 5    79      25      53     93
# 7    95       4      73     94
# 10   99      80      92      6
# 15   78      71      59     73
# 16   90      47      70     31
# 29   75      42      82     94
# 30   76      60      91     72
# 33   85      55      86     56
# 41   64      45      55     86
# 42   86      65      76     14
# 45   76      19      85     24
# 46   55      67      87     22
# 47   86      41      83     26
# 54   92      26      99     19
# 56   76      82      80     28
# 60   89      89      94     52
# 61   68      53      76     59
# 67   97      54      83     16
# 73   96      75      92     31
# 83   95      16      64     33
# 94   90      49      83     37

# %%
df1[filter1|filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    76      54      28      2
# 3    19      25     100     93
# 4    65      92      87     76
# 5    79      25      53     93
# 6    81      57       5     56
# ..  ...     ...     ...    ...
# 92   52      53      33      9
# 93   20      10      87     92
# 94   90      49      83     37
# 95    0      60      79     22
# 96   75       0      42     37
#
# [75 rows x 4 columns]
